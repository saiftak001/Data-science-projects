# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as py
import seaborn as sns

# %%
train_data = pd.read_excel('Data_Train.xlsx')

# %%
train_data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
test_data = pd.read_excel('Test_set.xlsx')

# %%
test_data
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# ...

# %%
big_df = train_data.append(test_data, sort= False)

# %%
big_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
big_df.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %% [markdown]
# ## Feature Engineering

# %%
big_df
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0                IndiGo      24/03/2019  Banglore   New Delhi
# 1             Air India       1/05/2019   Kolkata    Banglore
# 2           Jet Airways       9/06/2019     Delhi      Cochin
# 3                IndiGo      12/05/2019   Kolkata    Banglore
# 4                IndiGo      01/03/2019  Banglore   New Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                       Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                 BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1     CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
index_ = list(range(1,len(big_df)+1))

# %%
big_df.index = index_

# %%
big_df['Date'] = big_df['Date_of_Journey'].str.split('/').str[0]
big_df['Month'] = big_df['Date_of_Journey'].str.split('/').str[1]
big_df['Year'] = big_df['Date_of_Journey'].str.split('/').str[2]

# %%
big_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 1       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 2    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 3  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 4       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 5       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 1    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 2    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 3    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 4    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 5    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 1    03  2019
# 2    05  2019
# ...

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                object
# Month               object
# Year                object
# dtype: object

# %%
big_df['Date'] = big_df['Date'].astype('int')
big_df['Month'] = big_df['Month'].astype('int')
big_df['Year'] = big_df['Year'].astype('int')

# %%
big_df.dtypes
# Out:
# Airline             object
# Date_of_Journey     object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# dtype: object

# %%
big_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 1       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 2    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 3  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 4       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 5       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price  Date  \
# 1    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0    24
# 2    05:50         13:15   7h 25m     2 stops         No info   7662.0     1
# 3    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0     9
# 4    18:05         23:30   5h 25m      1 stop         No info   6218.0    12
# 5    16:50         21:35   4h 45m      1 stop         No info  13302.0     1
#
#    Month  Year
# 1      3  2019
# ...

# %%
big_df = big_df.drop(['Date_of_Journey'], axis=1)

# %%
big_df
# Out:
#                  Airline    Source Destination                  Route  \
# 1                 IndiGo  Banglore   New Delhi              BLR → DEL
# 2              Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 3            Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
# 4                 IndiGo   Kolkata    Banglore        CCU → NAG → BLR
# 5                 IndiGo  Banglore   New Delhi        BLR → NAG → DEL
# ...                  ...       ...         ...                    ...
# 13350          Air India   Kolkata    Banglore        CCU → DEL → BLR
# 13351             IndiGo   Kolkata    Banglore              CCU → BLR
# 13352        Jet Airways     Delhi      Cochin        DEL → BOM → COK
# 13353          Air India     Delhi      Cochin        DEL → BOM → COK
# 13354  Multiple carriers     Delhi      Cochin        DEL → BOM → COK
#
#       Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price  \
# ...

# %%
big_df['Arrival_Time'] = big_df['Arrival_Time'].str.split(' ').str[0]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 1       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 2    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 3  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 4       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 5       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 1        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 2        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 3        04:25      19h     2 stops         No info  13882.0     9      6
# 4        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 5        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 1  2019
# 2  2019
# 3  2019
# 4  2019
# 5  2019

# %%
big_df['Arrival_Hour'] = big_df['Arrival_Time'].str.split(':').str[0]
big_df['Arrival_Minute'] = big_df['Arrival_Time'].str.split(':').str[1]

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Arrival_Hour        object
# Arrival_Minute      object
# dtype: object

# %%
big_df['Arrival_Hour'] = big_df['Arrival_Hour'].astype('int')
big_df['Arrival_Minute'] = big_df['Arrival_Minute'].astype('int')

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Arrival_Time        object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Arrival_Hour         int32
# Arrival_Minute       int32
# dtype: object

# %%
big_df = big_df.drop(['Arrival_Time'], axis= 1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 1       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 2    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 3  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 4       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 5       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_Hour  \
# 1    non-stop         No info   3897.0    24      3  2019             1
# 2     2 stops         No info   7662.0     1      5  2019            13
# 3     2 stops         No info  13882.0     9      6  2019             4
# 4      1 stop         No info   6218.0    12      5  2019            23
# 5      1 stop         No info  13302.0     1      3  2019            21
#
#    Arrival_Minute
# 1              10
# 2              15
# ...

# %%
big_df['Dept_Hour'] = big_df['Dep_Time'].str.split(':').str[0]
big_df['Dept_Minute'] = big_df['Dep_Time'].str.split(':').str[1]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 1       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 2    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 3  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 4       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 5       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_Hour  \
# 1    non-stop         No info   3897.0    24      3  2019             1
# 2     2 stops         No info   7662.0     1      5  2019            13
# 3     2 stops         No info  13882.0     9      6  2019             4
# 4      1 stop         No info   6218.0    12      5  2019            23
# 5      1 stop         No info  13302.0     1      3  2019            21
#
#    Arrival_Minute Dept_Hour Dept_Minute
# ...

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Arrival_Hour         int32
# Arrival_Minute       int32
# Dept_Hour           object
# Dept_Minute         object
# dtype: object

# %%
big_df['Dept_Hour'] = big_df['Dept_Hour'].astype(int);
big_df['Dept_Minute'] = big_df['Dept_Minute'].astype(int);

# %%
big_df = big_df.drop(['Dep_Time'], axis = 1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 1       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 2    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 3  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 4       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 5       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_Hour  \
# 1    non-stop         No info   3897.0    24      3  2019             1
# 2     2 stops         No info   7662.0     1      5  2019            13
# 3     2 stops         No info  13882.0     9      6  2019             4
# 4      1 stop         No info   6218.0    12      5  2019            23
# 5      1 stop         No info  13302.0     1      3  2019            21
#
#    Arrival_Minute  Dept_Hour  Dept_Minute
# 1              10         22           20
# ...

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Arrival_Hour         int32
# Arrival_Minute       int32
# Dept_Hour            int32
# Dept_Minute          int32
# dtype: object

# %%
sns.heatmap(big_df.isnull(), cmap="Blues")

# %%
big_df[big_df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Duration Total_Stops Additional_Info  \
# 9040  Air India  Delhi      Cochin   NaN  23h 40m         NaN         No info
#
#        Price  Date  Month  Year  Arrival_Hour  Arrival_Minute  Dept_Hour  \
# 9040  7480.0     6      5  2019             9              25          9
#
#       Dept_Minute
# 9040           45

# %%
big_df['Total_Stops'] = big_df['Total_Stops'].fillna('1 stop')

# %%
sns.countplot(big_df['Total_Stops'])

# %%
big_df['Total_Stops'] = big_df['Total_Stops'].replace('non-stop', '0 stop')

# %%
sns.countplot(big_df['Total_Stops'])

# %%
big_df['Stop'] = big_df['Total_Stops'].str.split(' ').str[0]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 1       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 2    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 3  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 4       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 5       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_Hour  \
# 1      0 stop         No info   3897.0    24      3  2019             1
# 2     2 stops         No info   7662.0     1      5  2019            13
# 3     2 stops         No info  13882.0     9      6  2019             4
# 4      1 stop         No info   6218.0    12      5  2019            23
# 5      1 stop         No info  13302.0     1      3  2019            21
#
#    Arrival_Minute  Dept_Hour  Dept_Minute Stop
# 1              10         22           20    0
# ...

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Arrival_Hour         int32
# Arrival_Minute       int32
# Dept_Hour            int32
# Dept_Minute          int32
# Stop                object
# dtype: object

# %%
big_df['Stop'] = big_df['Stop'].astype('int')

# %%
big_df = big_df.drop(['Total_Stops'], axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 1       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 2    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 3  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 4       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 5       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  Arrival_Hour  Arrival_Minute  \
# 1         No info   3897.0    24      3  2019             1              10
# 2         No info   7662.0     1      5  2019            13              15
# 3         No info  13882.0     9      6  2019             4              25
# 4         No info   6218.0    12      5  2019            23              30
# 5         No info  13302.0     1      3  2019            21              35
#
#    Dept_Hour  Dept_Minute  Stop
# 1         22           20     0
# ...

# %%
big_df['Route1'] = big_df['Route'].str.split('→').str[0]
big_df['Route2'] = big_df['Route'].str.split('→').str[1]
big_df['Route3'] = big_df['Route'].str.split('→').str[2]
big_df['Route4'] = big_df['Route'].str.split('→').str[3]
big_df['Route5'] = big_df['Route'].str.split('→').str[4]
big_df['Route6'] = big_df['Route'].str.split('→').str[5]

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 1       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 2    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 3  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 4       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 5       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  ...  Arrival_Minute  Dept_Hour  \
# 1         No info   3897.0    24      3  2019  ...              10         22
# 2         No info   7662.0     1      5  2019  ...              15          5
# 3         No info  13882.0     9      6  2019  ...              25          9
# 4         No info   6218.0    12      5  2019  ...              30         18
# 5         No info  13302.0     1      3  2019  ...              35         16
#
#    Dept_Minute  Stop  Route1 Route2 Route3 Route4 Route5 Route6
# ...

# %%
big_df['Route1'].fillna("None", inplace=True)
big_df['Route2'].fillna("None", inplace=True)
big_df['Route3'].fillna("None", inplace=True)
big_df['Route4'].fillna("None", inplace=True)
big_df['Route5'].fillna("None", inplace=True)
big_df['Route6'].fillna("None", inplace=True)

# %%
big_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 1       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 2    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 3  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 4       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 5       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info    Price  Date  Month  Year  ...  Arrival_Minute  Dept_Hour  \
# 1         No info   3897.0    24      3  2019  ...              10         22
# 2         No info   7662.0     1      5  2019  ...              15          5
# 3         No info  13882.0     9      6  2019  ...              25          9
# 4         No info   6218.0    12      5  2019  ...              30         18
# 5         No info  13302.0     1      3  2019  ...              35         16
#
#    Dept_Minute  Stop  Route1 Route2 Route3 Route4 Route5 Route6
# ...

# %%
big_df = big_df.drop(['Route'], axis=1)

# %%
big_df[big_df['Route6'] !='None']
# Out:
#          Airline    Source Destination Duration  Additional_Info    Price  \
# 9183   Air India  Banglore   New Delhi  29h 30m  Change airports  17686.0
# 13106  Air India  Banglore   New Delhi   17h 5m          No info      NaN
#
#        Date  Month  Year  Arrival_Hour  Arrival_Minute  Dept_Hour  \
# 9183      1      3  2019            11              20          5
# 13106     1      3  2019            22              55          5
#
#        Dept_Minute  Stop Route1 Route2 Route3 Route4 Route5 Route6
# 9183            50     4   BLR    CCU    BBI    HYD    VGA     DEL
# 13106           50     4   BLR    CCU    BBI    HYD    VGA     DEL

# %%
sns.heatmap(big_df.isna(), cmap="Blues")

# %%
big_df['Price'].fillna((big_df['Price'].mean()), inplace= True)

# %%
sns.heatmap(big_df.isna())

# %%
big_df.head()
# Out:
#        Airline    Source Destination Duration Additional_Info    Price  Date  \
# 1       IndiGo  Banglore   New Delhi   2h 50m         No info   3897.0    24
# 2    Air India   Kolkata    Banglore   7h 25m         No info   7662.0     1
# 3  Jet Airways     Delhi      Cochin      19h         No info  13882.0     9
# 4       IndiGo   Kolkata    Banglore   5h 25m         No info   6218.0    12
# 5       IndiGo  Banglore   New Delhi   4h 45m         No info  13302.0     1
#
#    Month  Year  Arrival_Hour  Arrival_Minute  Dept_Hour  Dept_Minute  Stop  \
# 1      3  2019             1              10         22           20     0
# 2      5  2019            13              15          5           50     2
# 3      6  2019             4              25          9           25     2
# 4      5  2019            23              30         18            5     1
# 5      3  2019            21              35         16           50     1
#
#   Route1 Route2 Route3 Route4 Route5 Route6
# ...

# %%
big_df['Duration_hour'] = big_df['Duration'].str.split(' ').str[0]
big_df['Duration_minute'] = big_df['Duration'].str.split(' ').str[1]

# %%
big_df.Duration_minute[big_df['Duration_hour'].str.endswith('m')] = big_df['Duration_hour']
big_df.Duration_hour[big_df['Duration_hour'].str.endswith('m')] = 0
# Out:
# C:\Users\stak\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\stak\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
big_df.head()
# Out:
#        Airline    Source Destination Duration Additional_Info    Price  Date  \
# 1       IndiGo  Banglore   New Delhi   2h 50m         No info   3897.0    24
# 2    Air India   Kolkata    Banglore   7h 25m         No info   7662.0     1
# 3  Jet Airways     Delhi      Cochin      19h         No info  13882.0     9
# 4       IndiGo   Kolkata    Banglore   5h 25m         No info   6218.0    12
# 5       IndiGo  Banglore   New Delhi   4h 45m         No info  13302.0     1
#
#    Month  Year  Arrival_Hour  ...  Dept_Minute  Stop  Route1  Route2 Route3  \
# 1      3  2019             1  ...           20     0    BLR      DEL   None
# 2      5  2019            13  ...           50     2    CCU     IXR    BBI
# 3      6  2019             4  ...           25     2    DEL     LKO    BOM
# 4      5  2019            23  ...            5     1    CCU     NAG     BLR
# 5      3  2019            21  ...           50     1    BLR     NAG     DEL
#
# ...

# %%
big_df['Duration_hour']=big_df['Duration_hour'].str.replace('h','')
big_df['Duration_minute']=big_df['Duration_minute'].str.replace('m','')

# %%
big_df.head()
# Out:
#        Airline    Source Destination Duration Additional_Info    Price  Date  \
# 1       IndiGo  Banglore   New Delhi   2h 50m         No info   3897.0    24
# 2    Air India   Kolkata    Banglore   7h 25m         No info   7662.0     1
# 3  Jet Airways     Delhi      Cochin      19h         No info  13882.0     9
# 4       IndiGo   Kolkata    Banglore   5h 25m         No info   6218.0    12
# 5       IndiGo  Banglore   New Delhi   4h 45m         No info  13302.0     1
#
#    Month  Year  Arrival_Hour  ...  Dept_Minute  Stop  Route1  Route2 Route3  \
# 1      3  2019             1  ...           20     0    BLR      DEL   None
# 2      5  2019            13  ...           50     2    CCU     IXR    BBI
# 3      6  2019             4  ...           25     2    DEL     LKO    BOM
# 4      5  2019            23  ...            5     1    CCU     NAG     BLR
# 5      3  2019            21  ...           50     1    BLR     NAG     DEL
#
# ...

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Duration            object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Arrival_Hour         int32
# Arrival_Minute       int32
# Dept_Hour            int32
# Dept_Minute          int32
# Stop                 int32
# Route1              object
# Route2              object
# Route3              object
# Route4              object
# Route5              object
# Route6              object
# Duration_hour       object
# Duration_minute     object
# dtype: object

# %%
big_df.loc[6475]
# Out:
# Airline            Air India
# Source                Mumbai
# Destination        Hyderabad
# Duration                  5m
# Additional_Info      No info
# Price                  17327
# Date                       6
# Month                      3
# Year                    2019
# Arrival_Hour              16
# Arrival_Minute            55
# Dept_Hour                 16
# Dept_Minute               50
# Stop                       2
# Route1                  BOM
# Route2                  GOI
# Route3                  PNQ
# Route4                   HYD
# Route5                  None
# Route6                  None
# Duration_hour            NaN
# Duration_minute            5
# Name: 6475, dtype: object

# %%
sns.heatmap(big_df.isna(), cmap="Blues")

# %%
big_df.isna().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Duration              0
# Additional_Info       0
# Price                 0
# Date                  0
# Month                 0
# Year                  0
# Arrival_Hour          0
# Arrival_Minute        0
# Dept_Hour             0
# Dept_Minute           0
# Stop                  0
# Route1                0
# Route2                0
# Route3                0
# Route4                0
# Route5                0
# Route6                0
# Duration_hour         2
# Duration_minute    1284
# dtype: int64

# %%
big_df['Duration_minute'].fillna('0', inplace=True)
big_df['Duration_hour'].fillna('0', inplace=True)

# %%
sns.heatmap(big_df.isnull(), cmap= "Blues")

# %%
big_df['Duration_hour'] = big_df['Duration_hour'].astype('int')
big_df['Duration_minute'] = big_df['Duration_minute'].astype('int')

# %%
big_df.head()
# Out:
#        Airline    Source Destination Duration Additional_Info    Price  Date  \
# 1       IndiGo  Banglore   New Delhi   2h 50m         No info   3897.0    24
# 2    Air India   Kolkata    Banglore   7h 25m         No info   7662.0     1
# 3  Jet Airways     Delhi      Cochin      19h         No info  13882.0     9
# 4       IndiGo   Kolkata    Banglore   5h 25m         No info   6218.0    12
# 5       IndiGo  Banglore   New Delhi   4h 45m         No info  13302.0     1
#
#    Month  Year  Arrival_Hour  ...  Dept_Minute  Stop  Route1  Route2 Route3  \
# 1      3  2019             1  ...           20     0    BLR      DEL   None
# 2      5  2019            13  ...           50     2    CCU     IXR    BBI
# 3      6  2019             4  ...           25     2    DEL     LKO    BOM
# 4      5  2019            23  ...            5     1    CCU     NAG     BLR
# 5      3  2019            21  ...           50     1    BLR     NAG     DEL
#
# ...

# %%
big_df.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Duration            object
# Additional_Info     object
# Price              float64
# Date                 int32
# Month                int32
# Year                 int32
# Arrival_Hour         int32
# Arrival_Minute       int32
# Dept_Hour            int32
# Dept_Minute          int32
# Stop                 int32
# Route1              object
# Route2              object
# Route3              object
# Route4              object
# Route5              object
# Route6              object
# Duration_hour        int32
# Duration_minute      int32
# dtype: object

# %%
big_df = big_df.drop(['Duration'], axis=1)

# %%
big_df.head()
# Out:
#        Airline    Source Destination Additional_Info    Price  Date  Month  \
# 1       IndiGo  Banglore   New Delhi         No info   3897.0    24      3
# 2    Air India   Kolkata    Banglore         No info   7662.0     1      5
# 3  Jet Airways     Delhi      Cochin         No info  13882.0     9      6
# 4       IndiGo   Kolkata    Banglore         No info   6218.0    12      5
# 5       IndiGo  Banglore   New Delhi         No info  13302.0     1      3
#
#    Year  Arrival_Hour  Arrival_Minute  ...  Dept_Minute  Stop  Route1 Route2  \
# 1  2019             1              10  ...           20     0    BLR     DEL
# 2  2019            13              15  ...           50     2    CCU    IXR
# 3  2019             4              25  ...           25     2    DEL    LKO
# 4  2019            23              30  ...            5     1    CCU    NAG
# 5  2019            21              35  ...           50     1    BLR    NAG
#
# ...

# %%
big_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Additional_Info    0
# Price              0
# Date               0
# Month              0
# Year               0
# Arrival_Hour       0
# Arrival_Minute     0
# Dept_Hour          0
# Dept_Minute        0
# Stop               0
# Route1             0
# Route2             0
# Route3             0
# Route4             0
# Route5             0
# Route6             0
# Duration_hour      0
# Duration_minute    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder;

encoder = LabelEncoder();
big_df["Airline"]=encoder.fit_transform(big_df['Airline'])
big_df["Source"]=encoder.fit_transform(big_df['Source'])
big_df["Destination"]=encoder.fit_transform(big_df['Destination'])
big_df["Additional_Info"]=encoder.fit_transform(big_df['Additional_Info'])
big_df["Route1"]=encoder.fit_transform(big_df['Route1'])
big_df["Route2"]=encoder.fit_transform(big_df['Route2'])
big_df["Route3"]=encoder.fit_transform(big_df['Route3'])
big_df["Route4"]=encoder.fit_transform(big_df['Route4'])
big_df["Route5"]=encoder.fit_transform(big_df['Route5'])
big_df["Route6"]=encoder.fit_transform(big_df['Route6'])

# %%
big_df.head()
# Out:
#    Airline  Source  Destination  Additional_Info    Price  Date  Month  Year  \
# 1        3       0            5                8   3897.0    24      3  2019
# 2        1       3            0                8   7662.0     1      5  2019
# 3        4       2            1                8  13882.0     9      6  2019
# 4        3       3            0                8   6218.0    12      5  2019
# 5        3       0            5                8  13302.0     1      3  2019
#
#    Arrival_Hour  Arrival_Minute  ...  Dept_Minute  Stop  Route1  Route2  \
# 1             1              10  ...           20     0       0      13
# 2            13              15  ...           50     2       2      25
# 3             4              25  ...           25     2       3      32
# 4            23              30  ...            5     1       2      34
# 5            21              35  ...           50     1       0      34
#
#    Route3  Route4  Route5  Route6  Duration_hour  Duration_minute
# ...

# %% [markdown]
# ## Feature Selection

# %%
df_train = big_df[0:10683]
df_test = big_df[10683:]

# %%
x = df_train.drop(['Price'], axis = 1)
y = df_train.Price

# %% [markdown]
# ### Using Extra Tree Regressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()

# %%
from sklearn.model_selection import train_test_split;
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\stak\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=None,
#                     max_features='auto', max_leaf_nodes=None,
#                     min_impurity_decrease=0.0, min_impurity_split=None,
#                     min_samples_leaf=1, min_samples_split=2,
#                     min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#                     oob_score=False, random_state=None, verbose=0,
#                     warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [1.42136390e-01 9.09678431e-03 2.44988539e-02 5.39205452e-02
#  1.26811419e-01 4.71037182e-02 0.00000000e+00 2.11616056e-02
#  1.26132489e-02 1.92938352e-02 1.82037506e-02 1.05050908e-01
#  1.88138229e-02 4.89412773e-02 2.91880090e-01 2.11404297e-02
#  2.07583497e-04 0.00000000e+00 2.55151117e-02 1.36106259e-02]

# %%
feature_importance = pd.Series(model.feature_importances_, index= x.columns)
feature_importance.nlargest(20).plot(kind = 'barh')

# %% [markdown]
# ### Using Select From Model

# %%
from sklearn.linear_model import Lasso;
from sklearn.feature_selection import SelectFromModel;

# %%
select_model = SelectFromModel(Lasso(alpha=0.005, random_state=0))

# %%
select_model.fit(x_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, copy_X=True, fit_intercept=True,
#                                 max_iter=1000, normalize=False, positive=False,
#                                 precompute=False, random_state=0,
#                                 selection='cyclic', tol=0.0001,
#                                 warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
select_model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True])

# %%
x_train.columns[select_model.get_support()]
# Out:
# Index(['Airline', 'Source', 'Destination', 'Additional_Info', 'Date', 'Month',
#        'Arrival_Hour', 'Arrival_Minute', 'Dept_Hour', 'Dept_Minute', 'Stop',
#        'Route1', 'Route2', 'Route3', 'Route4', 'Route5', 'Duration_hour',
#        'Duration_minute'],
#       dtype='object')

# %%
x_train = x_train.drop(['Year','Route6'], axis=1)
x_test = x_test.drop(['Year','Route6'], axis=1)

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.model_selection import RandomizedSearchCV;
from sklearn.ensemble import RandomForestRegressor

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
random_model = RandomForestRegressor()

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf_random = RandomizedSearchCV(estimator=random_model, param_distributions=random_grid, scoring='neg_mean_squared_error'
                               , n_iter = 50, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.8s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.8s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# [CV]  n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5, total=   0.8s
# [CV] n_estimators=400, min_samples_split=100, min_samples_leaf=10, max_features=sqrt, max_depth=5
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 20}

# %%
predicted = rf_random.predict(x_test)

# %%
sns.distplot(y_test-predicted)

# %%
py.scatter(y_test, predicted)

# %%
from sklearn import metrics;
print('MAE:', metrics.mean_absolute_error(y_test, predicted))
print('MSE:', metrics.mean_squared_error(y_test, predicted))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predicted)))
# Out:
# MAE: 706.4473862525422
# MSE: 2667195.5723018777
# RMSE: 1633.1550974423335
